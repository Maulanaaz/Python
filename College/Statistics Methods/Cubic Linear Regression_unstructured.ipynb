# %%
import pandas as pd
data1 = pd.read_csv("Dataset/hardup.csv")
data2 = pd.read_csv("Dataset/perpen.csv")
data1 = data1.loc[data1.tahun==2020]
data2 = data2.loc[data2.tahun==2020]
data1 = data1.iloc[:,[4,5,6,7]]
data2 = data2.iloc[:,[4,5,6,7]]
data2
# Out:
#          nama_kabupaten_kota  persentase_penduduk  satuan  tahun
# 265          KABUPATEN BOGOR                 7.69  PERSEN   2020
# 266       KABUPATEN SUKABUMI                 7.09  PERSEN   2020
# 267        KABUPATEN CIANJUR                10.36  PERSEN   2020
# 268        KABUPATEN BANDUNG                 6.91  PERSEN   2020
# 269          KABUPATEN GARUT                 9.98  PERSEN   2020
# 270    KABUPATEN TASIKMALAYA                10.34  PERSEN   2020
# 271         KABUPATEN CIAMIS                 7.62  PERSEN   2020
# 272       KABUPATEN KUNINGAN                12.82  PERSEN   2020
# 273        KABUPATEN CIREBON                11.24  PERSEN   2020
# 274     KABUPATEN MAJALENGKA                11.43  PERSEN   2020
# 275       KABUPATEN SUMEDANG                10.26  PERSEN   2020
# 276      KABUPATEN INDRAMAYU                12.70  PERSEN   2020
# 277         KABUPATEN SUBANG                 9.31  PERSEN   2020
# ...

# %%
data3 = pd.merge(data1,data2,on="nama_kabupaten_kota")

# %%
data3
# Out:
#         nama_kabupaten_kota  angka_harapan_hidup satuan_x  tahun_x  \
# 0           KABUPATEN BOGOR                71.17    TAHUN     2020
# 1        KABUPATEN SUKABUMI                70.97    TAHUN     2020
# 2         KABUPATEN CIANJUR                70.13    TAHUN     2020
# 3         KABUPATEN BANDUNG                73.53    TAHUN     2020
# 4           KABUPATEN GARUT                71.41    TAHUN     2020
# 5     KABUPATEN TASIKMALAYA                69.47    TAHUN     2020
# 6          KABUPATEN CIAMIS                71.83    TAHUN     2020
# 7        KABUPATEN KUNINGAN                73.59    TAHUN     2020
# 8         KABUPATEN CIREBON                71.99    TAHUN     2020
# 9      KABUPATEN MAJALENGKA                70.27    TAHUN     2020
# 10       KABUPATEN SUMEDANG                72.43    TAHUN     2020
# 11      KABUPATEN INDRAMAYU                71.63    TAHUN     2020
# 12         KABUPATEN SUBANG                72.35    TAHUN     2020
# ...

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
arr1 = data3.angka_harapan_hidup.values
arr2 = data3.persentase_penduduk.values
arr1 = arr1.reshape(-1,1)
arr2 = arr2.reshape(-1,1)
model.fit(arr1,arr2)
# Out:
# LinearRegression()

# %%
data3.columns
# Out:
# Index(['nama_kabupaten_kota', 'jumlah_penduduk_miskin', 'satuan_x', 'tahun_x',
#        'persentase_penduduk', 'satuan_y', 'tahun_y'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.scatter(arr1,arr2)
plt.plot(arr1, model.predict(arr1))

# %%
data4 = pd.read_csv("Dataset/dekspen.csv")

# %%
data3 = data3.merge(data4,on="tahun")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from mpl_toolkits.mplot3d import Axes3D

data3 = pd.read_csv("hardupnperduk.csv")
data4 = pd.read_csv("Dataset/dekspen.csv")
data3 = data3.merge(data4,on="tahun")
######################################## Data preparation #########################################

X = data3[['indeks_pendidikan', 'persentase_penduduk']].values.reshape(-1,2)
Y = data3['angka_harapan_hidup']

######################## Prepare model data point for visualization ###############################

x = X[:, 0]
y = X[:, 1]
z = Y

x_pred = np.linspace(60, 14, 76)      # range of porosity values
y_pred = np.linspace(40, 14, 80)  # range of VR values
xx_pred, yy_pred = np.meshgrid(x_pred, y_pred)
model_viz = np.array([xx_pred.flatten(), yy_pred.flatten()]).T

################################################ Train #############################################

ols = linear_model.LinearRegression()
model = ols.fit(X, Y)
predicted = model.predict(model_viz)

############################################## Evaluate ############################################

r2 = model.score(X, Y)

############################################## Plot ################################################

plt.style.use('default')

fig = plt.figure(figsize=(12, 4))

ax1 = fig.add_subplot(131, projection='3d')
ax2 = fig.add_subplot(132, projection='3d')
ax3 = fig.add_subplot(133, projection='3d')

axes = [ax1, ax2, ax3]

for ax in axes:
    ax.plot(x, y, z, color='k', zorder=15, linestyle='none', marker='o', alpha=0.5)
    ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
    ax.set_xlabel('Porosity (%)', fontsize=12)
    ax.set_ylabel('VR', fontsize=12)
    ax.set_zlabel('Gas Prod. (Mcf/day)', fontsize=12)
    ax.locator_params(nbins=4, axis='x')
    ax.locator_params(nbins=5, axis='x')

ax1.text2D(0.2, 0.32, 'aegis4048.github.io', fontsize=13, ha='center', va='center',
           transform=ax1.transAxes, color='grey', alpha=0.5)
ax2.text2D(0.3, 0.42, 'aegis4048.github.io', fontsize=13, ha='center', va='center',
           transform=ax2.transAxes, color='grey', alpha=0.5)
ax3.text2D(0.85, 0.85, 'aegis4048.github.io', fontsize=13, ha='center', va='center',
           transform=ax3.transAxes, color='grey', alpha=0.5)

ax1.view_init(elev=27, azim=112)
ax2.view_init(elev=16, azim=-51)
ax3.view_init(elev=60, azim=165)

fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)

fig.tight_layout()

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
models = LinearRegression()
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6]).reshape(-1,1)
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86]).reshape(-1,1)
models.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x, models.predict(x))

# %%
X[:,0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9444\2973065910.py in <module>
# ----> 1 X[:,0]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from mpl_toolkits.mplot3d import Axes3D

######################################## Data preparation #########################################

file = 'https://aegis4048.github.io/downloads/notebooks/sample_data/unconv_MV_v5.csv'
df = pd.read_csv(file)

X = df[['Por', 'VR']].values.reshape(-1,2)
Y = df['Prod']

######################## Prepare model data point for visualization ###############################

x = X[:, 0]
y = X[:, 1]
z = Y

x_pred = np.linspace(6, 24, 30)      # range of porosity values
y_pred = np.linspace(0.93, 2.9, 30)  # range of VR values
xx_pred, yy_pred = np.meshgrid(x_pred, y_pred)
model_viz = np.array([xx_pred.flatten(), yy_pred.flatten()]).T

################################################ Train #############################################

ols = linear_model.LinearRegression()
model = ols.fit(X, Y)
predicted = model.predict(model_viz)

############################################## Evaluate ############################################

r2 = model.score(X, Y)

############################################## Plot ################################################

plt.style.use('default')

fig = plt.figure(figsize=(12, 4))

ax1 = fig.add_subplot(131, projection='3d')
ax2 = fig.add_subplot(132, projection='3d')
ax3 = fig.add_subplot(133, projection='3d')

axes = [ax1, ax2, ax3]

for ax in axes:
    ax.plot(x, y, z, color='k', zorder=15, linestyle='none', marker='o', alpha=0.5)
    ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
    ax.set_xlabel('Porosity (%)', fontsize=12)
    ax.set_ylabel('VR', fontsize=12)
    ax.set_zlabel('Gas Prod. (Mcf/day)', fontsize=12)
    ax.locator_params(nbins=4, axis='x')
    ax.locator_params(nbins=5, axis='x')

ax1.text2D(0.2, 0.32, 'aegis4048.github.io', fontsize=13, ha='center', va='center',
           transform=ax1.transAxes, color='grey', alpha=0.5)
ax2.text2D(0.3, 0.42, 'aegis4048.github.io', fontsize=13, ha='center', va='center',
           transform=ax2.transAxes, color='grey', alpha=0.5)
ax3.text2D(0.85, 0.85, 'aegis4048.github.io', fontsize=13, ha='center', va='center',
           transform=ax3.transAxes, color='grey', alpha=0.5)

ax1.view_init(elev=27, azim=112)
ax2.view_init(elev=16, azim=-51)
ax3.view_init(elev=60, azim=165)

fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)

fig.tight_layout()

# %%
X
# Out:
# array([[12.08,  2.31],
#        [12.38,  1.88],
#        [14.02,  2.72],
#        [17.67,  1.88],
#        [17.52,  1.9 ],
#        [14.53,  1.67],
#        [13.49,  1.85],
#        [11.58,  1.93],
#        [12.52,  1.98],
#        [13.25,  2.65],
#        [15.04,  1.77],
#        [16.19,  1.86],
#        [16.82,  1.98],
#        [17.39,  2.19],
#        [13.83,  1.64],
#        [11.34,  2.15],
#        [19.55,  1.95],
#        [15.58,  1.88],
#        [14.73,  1.98],
#        [12.47,  2.54],
#        [18.08,  2.09],
#        [16.32,  1.72],
#        [12.62,  1.48],
#        [10.03,  1.7 ],
#        [18.66,  1.71],
#        [ 7.27,  1.68],
#        [15.78,  2.04],
#        [15.73,  2.15],
#        [12.38,  2.07],
#        [12.89,  1.97],
#        [18.48,  2.45],
#        [14.74,  1.59],
#        [12.55,  2.27],
#        [13.58,  2.2 ],
#        [11.76,  2.45],
#        [11.98,  1.69],
#        [13.56,  1.93],
#        [16.55,  1.96],
#        [15.22,  2.26],
#        [14.54,  1.64],
# ...

# %%
df
# Out:
#      Well    Por  Perm    AI  Brittle   TOC    VR         Prod
# 0       1  12.08  2.92  2.80    81.40  1.16  2.31  4165.196191
# 1       2  12.38  3.53  3.22    46.17  0.89  1.88  3561.146205
# 2       3  14.02  2.59  4.01    72.80  0.89  2.72  4284.348574
# 3       4  17.67  6.75  2.63    39.81  1.08  1.88  5098.680869
# 4       5  17.52  4.57  3.18    10.94  1.51  1.90  3406.132832
# ..    ...    ...   ...   ...      ...   ...   ...          ...
# 195   196  11.95  3.13  2.97    67.18  0.80  2.06  3847.571003
# 196   197  17.99  9.87  3.38    44.32  0.98  2.08  5601.227131
# 197   198  12.12  2.27  3.52    57.07 -0.04  1.73  3409.575363
# 198   199  15.55  4.48  2.48    58.25  1.89  2.35  5087.592149
# 199   200  20.89  7.54  3.23    46.17  1.71  2.27  6662.622385
#
# [200 rows x 8 columns]

# %%
import numpy as np

#polynomial fit with degree = 2
model = np.poly1d(np.polyfit(data3.angka_harapan_hidup, data3.persentase_penduduk, 2))

#add fitted polynomial line to scatterplot
polyline = np.linspace(1, 60, 50)
plt.scatter(data3.angka_harapan_hidup, data3.persentase_penduduk)
plt.plot(polyline, model(polyline))
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score
import scipy.stats as stats
  
dataset = pd.read_csv("hardupnperduk.csv")

  
# degree 2 polynomial fit or quadratic fit
model = np.poly1d(np.polyfit(dataset['persentase_penduduk'],
                             dataset['angka_harapan_hidup'], 3))
  
# polynomial line visualization
polyline = np.linspace(0, 14, 76)
plt.scatter(dataset['persentase_penduduk'], dataset['angka_harapan_hidup'])
plt.plot(polyline, model(polyline))
plt.title("Persentase Penduduk Miskin vs Angka Harapan Hidup")
plt.xlabel('Persentase Penduduk Miskin')
plt.ylabel('Angka Harapan Hidup')
plt.show()
  
#print(model)
  
# r square metric
#print(r2_score(dataset['angka_harapan_hidup'], 
               #model(dataset['persentase_penduduk'])))

# %%
print(model)
# Out:
#          2
# 0.06925 x - 1.401 x + 78.6

# %%
data3 = data3.drop("tahun_x",axis="columns")

# %%
data3.rename(columns={'tahun_y':'tahun'},inplace=True)

# %%
data3.to_csv("hardupnperduk.csv",index=False)

# %%
len(data3)
# Out:
# 27

# %%
import numpy as np
m = np.array([[27,227.47,2121.4149,21193.5224],
             [227.47,2121.4149,21193,222442],
             [2121,21193,222442,2423244],
             [21193,222442,2423244,27177005]])
np.linalg.inv(m)
# Out:
# array([[ 9.78288486e+00, -4.09788941e+00,  5.18142148e-01,
#         -2.02883255e-02],
#        [-4.17168570e+00,  1.83853934e+00, -2.40372903e-01,
#          9.63780009e-03],
#        [ 5.34443332e-01, -2.43292643e-01,  3.26048967e-02,
#         -1.33266543e-03],
#        [-2.11376186e-02,  9.84051187e-03, -1.34384115e-03,
#          5.58005733e-05]])

# %%
p = np.array([[227],[16375],[152463],[1522255]])
p * m
# Out:
# array([[6.12900000e+03, 5.16356900e+04, 4.81561182e+05, 4.81092958e+06],
#        [3.72482125e+06, 3.47381690e+07, 3.47035375e+08, 3.64248775e+09],
#        [3.23374023e+08, 3.23114836e+09, 3.39141746e+10, 3.69455050e+11],
#        [3.22611502e+10, 3.38613447e+11, 3.68879530e+12, 4.13703317e+13]])

# %%
m * p
# Out:
# array([[6.12900000e+03, 3.72482125e+06, 3.23437280e+08, 3.22619454e+10],
#        [5.16356900e+04, 3.47381690e+07, 3.23114836e+09, 3.38613447e+11],
#        [4.81467000e+05, 3.47035375e+08, 3.39141746e+10, 3.68879530e+12],
#        [4.81081100e+06, 3.64248775e+09, 3.69455050e+11, 4.13703317e+13]])

# %%
np.matmul(m,p)
# Out:
# array([[3.25891137e+10],
#        [3.41879385e+11],
#        [3.72305699e+12],
#        [4.17434341e+13]])

# %%
p
# Out:
# array([    227,   16375,  152463, 1522255])

# %%
df = pd.read_csv("hardupnperduk.csv")
df
# Out:
#         nama_kabupaten_kota  angka_harapan_hidup satuan_x  \
# 0           KABUPATEN BOGOR                71.17    TAHUN
# 1        KABUPATEN SUKABUMI                70.97    TAHUN
# 2         KABUPATEN CIANJUR                70.13    TAHUN
# 3         KABUPATEN BANDUNG                73.53    TAHUN
# 4           KABUPATEN GARUT                71.41    TAHUN
# 5     KABUPATEN TASIKMALAYA                69.47    TAHUN
# 6          KABUPATEN CIAMIS                71.83    TAHUN
# 7        KABUPATEN KUNINGAN                73.59    TAHUN
# 8         KABUPATEN CIREBON                71.99    TAHUN
# 9      KABUPATEN MAJALENGKA                70.27    TAHUN
# 10       KABUPATEN SUMEDANG                72.43    TAHUN
# 11      KABUPATEN INDRAMAYU                71.63    TAHUN
# 12         KABUPATEN SUBANG                72.35    TAHUN
# 13     KABUPATEN PURWAKARTA                70.99    TAHUN
# 14       KABUPATEN KARAWANG                72.15    TAHUN
# ...

# %%
print(r2_score(dataset['angka_harapan_hidup'], 
               model(dataset['persentase_penduduk'])))
# Out:
# 0.53923367654835

# %%
print(model)
# Out:
#          3          2
# 0.01147 x - 0.2055 x + 0.5939 x + 74.38
